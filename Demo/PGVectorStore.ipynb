# %%
from langchain_core.documents import Document
from langchain_core.embeddings import DeterministicFakeEmbedding
from langchain_postgres import PGEngine, PGVectorStore

# Replace the connection string with your own Postgres connection string
CONNECTION_STRING = "postgresql+psycopg://langchain:langchain@localhost:6024/langchain"
engine = PGEngine.from_connection_string(url=CONNECTION_STRING)

# Replace the vector size with your own vector size
VECTOR_SIZE = 768
embedding = DeterministicFakeEmbedding(size=VECTOR_SIZE)

TABLE_NAME = "my_doc_collection"

engine.init_vectorstore_table(
    table_name=TABLE_NAME,
    vector_size=VECTOR_SIZE,
)

store = PGVectorStore.create_sync(
    engine=engine,
    table_name=TABLE_NAME,
    embedding_service=embedding,
)

docs = [
    Document(page_content="Apples and oranges"),
    Document(page_content="Cars and airplanes"),
    Document(page_content="Train")
]

store.add_documents(docs)

query = "I'd like a fruit."
docs = store.similarity_search(query)
print(docs)
# Out:
# ---------------------------------------------------------------------------
# ConnectionTimeout                         Traceback (most recent call last)
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\base.py:3309, in Engine.raw_connection(self)
#    3288 """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290 The returned object is a proxied version of the DBAPI
#    (...)   3307
#    3308 """
# -> 3309 return self.pool.connect()
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
#     442 The connection is instrumented such that when its
#    (...)    445
#     446 """
# --> 447 return _ConnectionFairy._checkout(self)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:388, in Pool._create_connection(self)
#     386 """Called by subclasses to create a new ConnectionRecord."""
# --> 388 return _ConnectionRecord(self)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:899, in _ConnectionRecord.__connect(self)
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:895, in _ConnectionRecord.__connect(self)
#     894 self.starttime = time.time()
# --> 895 self.dbapi_connection = connection = pool._invoke_creator(self)
#     896 pool.logger.debug("Created new connection %r", connection)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\create.py:661, in create_engine.<locals>.connect(connection_record)
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\dialects\postgresql\psycopg.py:812, in PsycopgAdaptDBAPI.connect(self, *arg, **kw)
#     810 else:
#     811     return AsyncAdapt_psycopg_connection(
# --> 812         await_only(creator_fn(*arg, **kw))
#     813     )
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\_concurrency_py3k.py:132, in await_only(awaitable)
#     128 # returns the control to the driver greenlet passing it
#     129 # a coroutine to run. Once the awaitable is done, the driver greenlet
#     130 # switches back to this greenlet with the result of awaitable that is
#     131 # then returned to the caller (or raised as error)
# --> 132 return current.parent.switch(awaitable)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\_concurrency_py3k.py:196, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     193 try:
#     194     # wait for a coroutine from await_only and then return its
#     195     # result back to it.
# --> 196     value = await result
#     197 except BaseException:
#     198     # this allows an exception to be raised within
#     199     # the moderated greenlet so that it can continue
#     200     # its expected flow.
#
# File D:\anaconda\envs\xsf\Lib\site-packages\psycopg\connection_async.py:146, in AsyncConnection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     145     new_ex = type(last_ex)("\n".join(lines), pgconn=last_ex.pgconn)
# --> 146     raise new_ex.with_traceback(None)
#     148 if (
#     149     capabilities.has_used_gssapi()
#     150     and rv.pgconn.used_gssapi
#     151     and not gssapi_requested(params)
#     152 ):
#
# ConnectionTimeout: connection timeout expired
# Multiple connection attempts failed. All failures were:
# - host: 'localhost', port: 6024, hostaddr: '::1': connection timeout expired
# - host: 'localhost', port: 6024, hostaddr: '127.0.0.1': connection timeout expired
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 15
#      11 embedding = DeterministicFakeEmbedding(size=VECTOR_SIZE)
#      13 TABLE_NAME = "my_doc_collection"
# ---> 15 engine.init_vectorstore_table(
#      16     table_name=TABLE_NAME,
#      17     vector_size=VECTOR_SIZE,
#      18 )
#      20 store = PGVectorStore.create_sync(
#      21     engine=engine,
#      22     table_name=TABLE_NAME,
#      23     embedding_service=embedding,
#      24 )
#      26 docs = [
#      27     Document(page_content="Apples and oranges"),
#      28     Document(page_content="Cars and airplanes"),
#      29     Document(page_content="Train")
#      30 ]
#
# File D:\anaconda\envs\xsf\Lib\site-packages\langchain_postgres\v2\engine.py:364, in PGEngine.init_vectorstore_table(self, table_name, vector_size, schema_name, content_column, embedding_column, metadata_columns, metadata_json_column, id_column, overwrite_existing, store_metadata, hybrid_search_config)
#     323 def init_vectorstore_table(
#     324     self,
#     325     table_name: str,
#    (...)    336     hybrid_search_config: Optional[HybridSearchConfig] = None,
#     337 ) -> None:
#     338     """
#     339     Create a table for saving of vectors to be used with PGVectorStore.
#     340
#    (...)    362             Default: None.
#     363     """
# --> 364     self._run_as_sync(
#     365         self._ainit_vectorstore_table(
#     366             table_name,
#     367             vector_size,
#     368             schema_name=schema_name,
#     369             content_column=content_column,
#     370             embedding_column=embedding_column,
#     371             metadata_columns=metadata_columns,
#     372             metadata_json_column=metadata_json_column,
#     373             id_column=id_column,
#     374             overwrite_existing=overwrite_existing,
#     375             store_metadata=store_metadata,
#     376             hybrid_search_config=hybrid_search_config,
#     377         )
#     378     )
#
# File D:\anaconda\envs\xsf\Lib\site-packages\langchain_postgres\v2\engine.py:131, in PGEngine._run_as_sync(self, coro)
#     127 if not self._loop:
#     128     raise Exception(
#     129         "Engine was initialized without a background loop and cannot call sync methods."
#     130     )
# --> 131 return asyncio.run_coroutine_threadsafe(coro, self._loop).result()
#
# File D:\anaconda\envs\xsf\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File D:\anaconda\envs\xsf\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File D:\anaconda\envs\xsf\Lib\site-packages\langchain_postgres\v2\engine.py:214, in PGEngine._ainit_vectorstore_table(self, table_name, vector_size, schema_name, content_column, embedding_column, metadata_columns, metadata_json_column, id_column, overwrite_existing, store_metadata, hybrid_search_config)
#     211     self._validate_column_dict(id_column)
#     212     id_column["name"] = self._escape_postgres_identifier(id_column["name"])
# --> 214 async with self._pool.connect() as conn:
#     215     await conn.execute(text("CREATE EXTENSION IF NOT EXISTS vector"))
#     216     await conn.commit()
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\ext\asyncio\base.py:121, in StartableContext.__aenter__(self)
#     120 async def __aenter__(self) -> _T_co:
# --> 121     return await self.start(is_ctxmanager=True)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\ext\asyncio\engine.py:275, in AsyncConnection.start(self, is_ctxmanager)
#     272 if self.sync_connection:
#     273     raise exc.InvalidRequestError("connection is already started")
#     274 self.sync_connection = self._assign_proxied(
# --> 275     await greenlet_spawn(self.sync_engine.connect)
#     276 )
#     277 return self
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\_concurrency_py3k.py:201, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     196     value = await result
#     197 except BaseException:
#     198     # this allows an exception to be raised within
#     199     # the moderated greenlet so that it can continue
#     200     # its expected flow.
# --> 201     result = context.throw(*sys.exc_info())
#     202 else:
#     203     result = context.switch(value)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\base.py:3285, in Engine.connect(self)
#    3262 def connect(self) -> Connection:
#    3263     """Return a new :class:`_engine.Connection` object.
#    3264
#    3265     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3282
#    3283     """
# -> 3285     return self._connection_cls(self)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\base.py:2448, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2446 elif should_wrap:
#    2447     assert sqlalchemy_exception is not None
# -> 2448     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2449 else:
#    2450     assert exc_info[1] is not None
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\base.py:3309, in Engine.raw_connection(self)
#    3287 def raw_connection(self) -> PoolProxiedConnection:
#    3288     """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290     The returned object is a proxied version of the DBAPI
#    (...)   3307
#    3308     """
# -> 3309     return self.pool.connect()
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     439 def connect(self) -> PoolProxiedConnection:
#     440     """Return a DBAPI connection from the pool.
#     441
#     442     The connection is instrumented such that when its
#    (...)    445
#     446     """
# --> 447     return _ConnectionFairy._checkout(self)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     709     rec = cast(_ConnectionRecord, pool._do_get())
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#     714     dbapi_connection = rec.get_connection()
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:388, in Pool._create_connection(self)
#     385 def _create_connection(self) -> ConnectionPoolEntry:
#     386     """Called by subclasses to create a new ConnectionRecord."""
# --> 388     return _ConnectionRecord(self)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     671 self.__pool = pool
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:899, in _ConnectionRecord.__connect(self)
#     897     self.fresh = True
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#     901 else:
#     902     # in SQLAlchemy 1.4 the first_connect event is not used by
#     903     # the engine, so this will usually not be set
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\pool\base.py:895, in _ConnectionRecord.__connect(self)
#     893 try:
#     894     self.starttime = time.time()
# --> 895     self.dbapi_connection = connection = pool._invoke_creator(self)
#     896     pool.logger.debug("Created new connection %r", connection)
#     897     self.fresh = True
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\create.py:661, in create_engine.<locals>.connect(connection_record)
#     658         if connection is not None:
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\dialects\postgresql\psycopg.py:812, in PsycopgAdaptDBAPI.connect(self, *arg, **kw)
#     807     return AsyncAdaptFallback_psycopg_connection(
#     808         await_fallback(creator_fn(*arg, **kw))
#     809     )
#     810 else:
#     811     return AsyncAdapt_psycopg_connection(
# --> 812         await_only(creator_fn(*arg, **kw))
#     813     )
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\_concurrency_py3k.py:132, in await_only(awaitable)
#     123     raise exc.MissingGreenlet(
#     124         "greenlet_spawn has not been called; can't call await_only() "
#     125         "here. Was IO attempted in an unexpected place?"
#     126     )
#     128 # returns the control to the driver greenlet passing it
#     129 # a coroutine to run. Once the awaitable is done, the driver greenlet
#     130 # switches back to this greenlet with the result of awaitable that is
#     131 # then returned to the caller (or raised as error)
# --> 132 return current.parent.switch(awaitable)
#
# File D:\anaconda\envs\xsf\Lib\site-packages\sqlalchemy\util\_concurrency_py3k.py:196, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     192 switch_occurred = True
#     193 try:
#     194     # wait for a coroutine from await_only and then return its
#     195     # result back to it.
# --> 196     value = await result
#     197 except BaseException:
#     198     # this allows an exception to be raised within
#     199     # the moderated greenlet so that it can continue
#     200     # its expected flow.
#     201     result = context.throw(*sys.exc_info())
#
# File D:\anaconda\envs\xsf\Lib\site-packages\psycopg\connection_async.py:146, in AsyncConnection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     144     lines.extend(f"- {descr}: {error}" for error, descr in conn_errors)
#     145     new_ex = type(last_ex)("\n".join(lines), pgconn=last_ex.pgconn)
# --> 146     raise new_ex.with_traceback(None)
#     148 if (
#     149     capabilities.has_used_gssapi()
#     150     and rv.pgconn.used_gssapi
#     151     and not gssapi_requested(params)
#     152 ):
#     153     warnings.warn(
#     154         "the connection was obtained using the GSSAPI relying on the"
#     155         " 'gssencmode=prefer' libpq default. The value for this default might"
#    (...)    160         RuntimeWarning,
#     161     )
#
# OperationalError: (psycopg.errors.ConnectionTimeout) connection timeout expired
# Multiple connection attempts failed. All failures were:
# - host: 'localhost', port: 6024, hostaddr: '::1': connection timeout expired
# - host: 'localhost', port: 6024, hostaddr: '127.0.0.1': connection timeout expired
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
